# %%
import requests

# %%
url = 'http://webservice.recruit.co.jp/hotpepper/gourmet/v1/'

# %%
params = {
    'key':'81bca6bf407ec168',
    'keyword':'焼き肉',
    'format':'json',
    'count':100
}

# %%
res  = requests.get(url, params)
res
# Out:
# <Response [200]>

# %%
shops = res.json()['results']['shop']
shop = shops[3]
shop['name']
# Out:
# '焼肉食べ放題 タレる 梅田店'

# %%
shop['address']
# Out:
# '大阪府大阪市北区堂山町7-7角庄ビル7Ｆ'

# %%
res.json()
# Out:
# {'results': {'api_version': '1.26',
#   'results_available': 248,
#   'results_returned': '100',
#   'results_start': 1,
#   'shop': [{'access': 'ＪＲ 千葉駅徒歩3分◆30%割引開催中！さらに幹事無料最大3名様まで対応中！',
#     'address': '千葉県千葉市中央区富士見２-4-9ラフィネビル5F',
#     'band': '不可',
#     'barrier_free': 'なし',
#     'budget': {'average': 'お得な飲み放題付コース3500円~！OPEN割引も開催中！',
#      'code': 'B003',
#      'name': '3001～4000円'},
#     'budget_memo': '',
#     'capacity': 80,
#     'card': '利用可',
#     'catch': '肉寿司,溶岩焼き,牛タン お得なクーポン多数♪',
#     'charter': '貸切可',
#     'child': 'お子様連れ歓迎',
#     'close': 'なし',
#     'coupon_urls': {'pc': 'https://www.hotpepper.jp/strJ001275309/map/?vos=nhppalsa000016',
#      'sp': 'https://www.hotpepper.jp/strJ001275309/scoupon/?vos=nhppalsa000016'},
#     'course': 'あり',
#     'english': 'あり',
#     'free_drink': 'あり',
#     'free_food': 'なし',
#     'genre': {'catch': '千葉 肉 肉刺し 飲み放題 個室 もつ鍋 焼肉',
#      'code': 'G001',
#      'name': '居酒屋'},
#     'horigotatsu': 'あり',
# ...
